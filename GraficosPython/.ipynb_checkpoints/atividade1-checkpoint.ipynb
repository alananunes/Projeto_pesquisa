# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=['MEDICINA','FISIOTERAPIA','DIREITO','ODONTOLOGIA', 'MEDICINA VETERINARIA', 'PILOTAGEM PROFISSONAL','ENGENHARIA CIVIL','ENFERMAGEM','ARQUITETURA','NUTRICAO']
Y=[9804.16,5600,5077,4902,4592,3542.33,3087.91,2900.29,2867,2713]

# %%
plt.scatter(x,Y,color='b', s=200, alpha=0.60)
plt.figure(figsize=(8,5))
plt.show()
